# %%
# Datascience lesson - Quant and Qual_Placement data file_Practicals

# %%
import pandas as pd

# %%
dataset = pd.read_csv("Placement.csv")
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
dataset.columns
# Out:
# Index(['sl_no', 'gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s',
#        'degree_p', 'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p',
#        'status', 'salary'],
#       dtype='object')

# %%
#qual = ['gender','ssc_b','hsc_b','hsc_s','degree_t,'workex','specialisation','status']
#quant = ['ssc_p','hsc_p','degree_p','etest_p',mba_p','salary']

# %%
dataset.dtypes
# Out:
# sl_no               int64
# gender             object
# ssc_p             float64
# ssc_b              object
# hsc_p             float64
# hsc_b              object
# hsc_s              object
# degree_p          float64
# degree_t           object
# workex             object
# etest_p           float64
# specialisation     object
# mba_p             float64
# status             object
# salary            float64
# dtype: object

# %%
dataset["gender"].dtypes
# Out:
# dtype('O')

# %%
dataset["ssc_p"].dtypes
# Out:
# dtype('float64')

# %%
for columnname in dataset.columns:
    print (columnname)
# Out:
# sl_no
# gender
# ssc_p
# ssc_b
# hsc_p
# hsc_b
# hsc_s
# degree_p
# degree_t
# workex
# etest_p
# specialisation
# mba_p
# status
# salary

# %%
if (dataset["gender"].dtypes=='str'):
    print ('qualitative')
else:
    print ('quantitative')
# Out:
# quantitative

# %%
if (dataset["ssc_p"].dtypes=='str'):
    print ('qualitative')
else:
    print ('quantitative')
# Out:
# quantitative

# %%
quan=[]
qual=[]
for columnname in dataset.columns:
    print (columnname)
    if (dataset[columnname].dtypes=='str'):
        print ('qualitative')
        qual.append (columnname)
    else:
        print ('quantitative')
        quan.append (columnname)
# Out:
# sl_no
# quantitative
# gender
# quantitative
# ssc_p
# quantitative
# ssc_b
# quantitative
# hsc_p
# quantitative
# hsc_b
# quantitative
# hsc_s
# quantitative
# degree_p
# quantitative
# degree_t
# quantitative
# workex
# quantitative
# etest_p
# quantitative
# specialisation
# quantitative
# mba_p
# quantitative
# status
# quantitative
# salary
# quantitative

# %%
quan
# Out:
# ['sl_no',
#  'gender',
#  'ssc_p',
#  'ssc_b',
#  'hsc_p',
#  'hsc_b',
#  'hsc_s',
#  'degree_p',
#  'degree_t',
#  'workex',
#  'etest_p',
#  'specialisation',
#  'mba_p',
#  'status',
#  'salary']

# %%
qual
# Out:
# []

# %%
def quanqual(dataset):
    quan=[]
    qual=[]
    for columnname in dataset.columns:
        print (columnname)
        if (dataset[columnname].dtypes=='str'):
            print ('qualitative')
            qual.append (columnname)
        else:
            print ('quantitative')
            quan.append (columnname)
    return quan,qual

# %%
quan,qual=quanqual(dataset)
# Out:
# sl_no
# quantitative
# gender
# quantitative
# ssc_p
# quantitative
# ssc_b
# quantitative
# hsc_p
# quantitative
# hsc_b
# quantitative
# hsc_s
# quantitative
# degree_p
# quantitative
# degree_t
# quantitative
# workex
# quantitative
# etest_p
# quantitative
# specialisation
# quantitative
# mba_p
# quantitative
# status
# quantitative
# salary
# quantitative

# %%
quan
# Out:
# ['sl_no',
#  'gender',
#  'ssc_p',
#  'ssc_b',
#  'hsc_p',
#  'hsc_b',
#  'hsc_s',
#  'degree_p',
#  'degree_t',
#  'workex',
#  'etest_p',
#  'specialisation',
#  'mba_p',
#  'status',
#  'salary']

# %%
qual
# Out:
# []

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Central Tendency

# %%
dataset["ssc_p"].mean()
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()
# Out:
# 67.0

# %%
dataset["ssc_p"].mode()[0]
# Out:
# np.float64(62.0)

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)

# %%
descriptive
# Out:
#        sl_no gender ssc_p ssc_b hsc_p hsc_b hsc_s degree_p degree_t workex  \
# Mean     NaN    NaN   NaN   NaN   NaN   NaN   NaN      NaN      NaN    NaN
# Median   NaN    NaN   NaN   NaN   NaN   NaN   NaN      NaN      NaN    NaN
# Mode     NaN    NaN   NaN   NaN   NaN   NaN   NaN      NaN      NaN    NaN
#
#        etest_p specialisation mba_p status salary
# Mean       NaN            NaN   NaN    NaN    NaN
# Median     NaN            NaN   NaN    NaN    NaN
# Mode       NaN            NaN   NaN    NaN    NaN

# %%
descriptive.loc["hsc_p","Mean"]=0

# %%
descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
for columnName in quan:
    descriptive.loc["Mean",columnName]=dataset[columnName].mean()
    descriptive.loc["Median",columnName]=dataset[columnName].median()
    descriptive.loc["Mode",columnName]=dataset[columnName].mode()[0]
print(descriptive)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 3
#       1 descriptive=pd.DataFrame(index=["Mean","Median","Mode"],columns=quan)
#       2 for columnName in quan:
# ----> 3     descriptive.loc["Mean",columnName]=dataset[columnName].mean()
#       4     descriptive.loc["Median",columnName]=dataset[columnName].median()
#       5     descriptive.loc["Mode",columnName]=dataset[columnName].mode()[0]
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File C:\Anaconda3\Lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
# ...

# %%
descriptive
# Out:
#         sl_no gender ssc_p ssc_b hsc_p hsc_b hsc_s degree_p degree_t workex  \
# Mean    108.0    NaN   NaN   NaN   NaN   NaN   NaN      NaN      NaN    NaN
# Median  108.0    NaN   NaN   NaN   NaN   NaN   NaN      NaN      NaN    NaN
# Mode        1    NaN   NaN   NaN   NaN   NaN   NaN      NaN      NaN    NaN
#
#        etest_p specialisation mba_p status salary
# Mean       NaN            NaN   NaN    NaN    NaN
# Median     NaN            NaN   NaN    NaN    NaN
# Mode       NaN            NaN   NaN    NaN    NaN
